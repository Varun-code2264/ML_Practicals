# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun-code2264/ML_Practicals/blob/main/ML_LAB_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace 'your_dataset.csv' with your dataset file path
data = pd.read_csv('C:\Users\PLACEMENT\Downloads\data.csv')

print(data.head())
print(data.columns)
# Out:
#   File "/tmp/ipython-input-2614284990.py", line 4
#     data = pd.read_csv('C:\Users\PLACEMENT\Downloads\data.csv')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# Replace 'your_dataset.csv' with your dataset file path
data = pd.read_csv('/data.csv')

print(data.head())
print(data.columns)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...
